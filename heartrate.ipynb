# %%
# Imports, leave this

import numpy as np
import scipy
import csv
import pandas as pd
import glob
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
# Specify path to the CSV file containing HR data

df_hrs = pd.read_csv('/Users/joostplattel/1Inbox/vpro/vpro-data/data/hr.csv', delimiter=';')
df_hrs = pd.DataFrame(df_hrs)

# %%
# plot graph tim
df_tim = df_hrs[(df_hrs['name'] == "tim")]
df_tim = df_tim['rate']
df_tim.plot() # Plot it

# %%
# plot graph nicolaas 
df_nic = df_hrs[(df_hrs['name'] == "nicolaas")]
df_nic = df_nic['rate']
df_nic.plot()

# %%
# distibutie tim
df_tim.hist(bins=50)

# %%
# distibutie nicolaas
df_nic.hist(bins=50)
